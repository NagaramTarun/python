# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaramTarun/python/blob/main/Day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2.56789,9,87.9999,40,'hyderabad']
k
# Out:
# [4, 2.56789, 9, 87.9999, 40, 'hyderabad']

# %%
pd.Series(k)
# Out:
# 0            4
# 1      2.56789
# 2            9
# 3      87.9999
# 4           40
# 5    hyderabad
# dtype: object

# %%
a = np.random.randint(20,50,15)
a
# Out:
# array([22, 46, 30, 31, 22, 29, 46, 26, 44, 22, 26, 30, 20, 31, 41])

# %%
pd.Series(a)
# Out:
# 0     22
# 1     46
# 2     30
# 3     31
# 4     22
# 5     29
# 6     46
# 7     26
# 8     44
# 9     22
# 10    26
# 11    30
# 12    20
# 13    31
# 14    41
# dtype: int64

# %%
np.random.seed(34)
b = np.random.randint(100,200,(6,5))
b
# Out:
# array([[133, 185, 168, 135, 169],
#        [111, 178, 129, 118, 129],
#        [189, 129, 120, 196, 162],
#        [105, 120, 151, 119, 185],
#        [121, 163, 172, 142, 184],
#        [172, 177, 136, 102, 137]])

# %%
b.ndim
# Out:
# 2

# %%
df=pd.DataFrame(b,columns=['Roll','name','age','adds','country'],index=[182,183,185,186,187,188])
df
# Out:
#      Roll  name  age  adds  country
# 182   133   185  168   135      169
# 183   111   178  129   118      129
# 185   189   129  120   196      162
# 186   105   120  151   119      185
# 187   121   163  172   142      184
# 188   172   177  136   102      137

# %%
df.loc[187]
# Out:
# Roll       121
# name       163
# age        172
# adds       142
# country    184
# Name: 187, dtype: int64

# %%
df.iloc[[1,3,4]]
# Out:
#      Roll  name  age  adds  country
# 183   111   178  129   118      129
# 186   105   120  151   119      185
# 187   121   163  172   142      184

# %%
df.age
# Out:
# 182    168
# 183    129
# 185    120
# 186    151
# 187    172
# 188    136
# Name: age, dtype: int64

# %%
df['age']
# Out:
# 182    168
# 183    129
# 185    120
# 186    151
# 187    172
# 188    136
# Name: age, dtype: int64

# %%
df[['adds','age']]
# Out:
#      adds  age
# 182   135  168
# 183   118  129
# 185   196  120
# 186   119  151
# 187   142  172
# 188   102  136

# %%
df.loc[[182,185,186],['adds','name','Roll']]
# Out:
#      adds  name  Roll
# 182   135   185   133
# 185   196   129   189
# 186   119   120   105

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df1=sns.load_dataset('titanic')
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (6, 5)

# %%
df1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
