# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaramTarun/python/blob/main/day25%2626.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cars = pd.read_csv(r'/content/Cars.csv')

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %% [markdown]
# # ***EDA***
#  1. displot
#  2.box plot
#  3. scatterplot

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(cars["HP"])
plt.show()

# %%
sns.distplot(cars['MPG'])
plt.show()

# %%
sns.distplot(cars['VOL'])
plt.show()

# %%
sns.distplot(cars['WT'])
plt.show()

# %%
sns.distplot(cars['SP'])
plt.show()

# %%
sns.boxplot(cars['HP'])
# Out:
# <Axes: ylabel='HP'>

# %%
sns.boxplot(cars['MPG'])
# Out:
# <Axes: ylabel='MPG'>

# %%
sns.boxplot(cars['VOL'])
# Out:
# <Axes: ylabel='VOL'>

# %%
sns.boxplot(cars['WT'])
# Out:
# <Axes: ylabel='WT'>

# %%
sns.boxplot(cars['SP'])
# Out:
# <Axes: ylabel='SP'>

# %%
sns.scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
sns.scatterplot(x=cars['WT'],y=cars['MPG'])
# Out:
# <Axes: xlabel='WT', ylabel='MPG'>

# %%
sns.scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
sns.scatterplot(x=cars['SP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %% [markdown]
# # ***CORRELATION MATRIX***

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(np.abs(cars.corr()),cmap='Blues',annot=True)
plt.show()

# %%
sns.scatterplot(x='HP',y='VOL',data=cars)
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.scatterplot(x='HP',y='SP',data=cars)
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.scatterplot(x='HP',y='WT',data=cars)
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
sns.scatterplot(x='VOL',y='SP',data=cars)
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
sns.scatterplot(x='VOL',y='WT',data=cars)
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
sns.scatterplot(x='SP',y='WT',data=cars)
# Out:
# <Axes: xlabel='SP', ylabel='WT'>
